# %%
thisset = {"apple", "banana", "cherry"}
mylist = ["kiwi", "orange"]

thisset.update(mylist)

print(thisset)
# Out:
# {'kiwi', 'apple', 'banana', 'cherry', 'orange'}

# %%
thisset.add('shshhs')
print(thisset)
# Out:
# {'shshhs', 'kiwi', 'apple', 'banana', 'cherry', 'orange'}
